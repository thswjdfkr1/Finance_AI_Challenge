# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -U langchain-community
# !pip install -U transformers
# !pip install -U bitsandbytes accelerate
# # !pip install datasets
# !pip install pypdf
# !pip install peft
# !pip install langchain
# !pip install langchain-huggingface faiss-cpu
# !pip install rank_bm25
# !pip install langchain-huggingface

# %%
# !pip install --upgrade --force-reinstall autoawq --extra-index-url https://download.pytorch.org/whl/cu121
# !pip uninstall -y autoawq
# !git clone https://github.com/casper-hansen/AutoAWQ.git
# %cd AutoAWQ
# !pip install .

# %%
import re
import json
import torch
import pandas as pd
import numpy as np
import glob

import tqdm
from statistics import mean
from datasets import Dataset, load_dataset
from typing import List, Dict

from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training
from peft import PeftModelForCausalLM
from peft import AutoPeftModelForCausalLM
from peft import prepare_model_for_kbit_training

from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments, Trainer, pipeline, BitsAndBytesConfig
from transformers import EarlyStoppingCallback
from transformers import default_data_collator

from langchain.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.retrievers import BM25Retriever, EnsembleRetriever
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_core.prompts import PromptTemplate
from langchain_core.documents import Document
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from langchain_community.llms import HuggingFacePipeline
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

from rank_bm25 import BM25Okapi
import pickle

from google.colab import files
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # retriever

# %% [markdown]
# ## pdf load & split chunks

# %%
# pdf 로드
pdf_folder = "/content/drive/MyDrive/1데이콘/2025금융AIChallenge금융AI모델경쟁/dataset/pdf/*.pdf"
pdf_files = glob.glob(pdf_folder)

# %%
all_chunks = []

def split_chunks(pdf_files):
  for pdf_file in tqdm.tqdm(pdf_files, desc = 'Pdf Load'):
    loader = PyPDFLoader(pdf_file)
    docs = loader.load()

    # 불필요한 문자 제거
    pattern = r'[①-⑳◆·「」｢｣□◦\-\*❶-❸Ⅲ※‧Ÿ]'
    for doc in docs:
      text = doc.page_content
      text = re.sub(pattern, ' ', text)
      text = re.sub(r'\n', ' ', text)
      text = re.sub(r'\s+', ' ', text)
      text = text.strip()
      doc.page_content = text

    paragraph_lengths = [len(doc.page_content) for doc in docs]

    print()
    print("문단 개수:", len(paragraph_lengths))
    print("평균 문단 길이:", round(mean(paragraph_lengths)))
    print("최소 문단 길이:", min(paragraph_lengths))
    print("최대 문단 길이:", max(paragraph_lengths))

    # 추천 chunk_size & overlap 계산
    avg_len = mean(paragraph_lengths)
    max_len = max(paragraph_lengths)

    # chunk_size는 최대 문단 길이보다 조금 크게, 평균의 2~3배 정도로 설정
    chunk_size = int(min(max_len * 1.1, avg_len * 3))
    chunk_overlap = int(chunk_size * 0.15)  # 15% 정도 겹치기

    print("추천 chunk_size:", chunk_size)
    print("추천 chunk_overlap:", chunk_overlap)

    text_spliter = RecursiveCharacterTextSplitter(
      chunk_size = chunk_size,
      chunk_overlap = chunk_overlap,
      separators = ["\n\n", "\n", " ", ""]
      )

    split_chunks = text_spliter.split_documents(docs)
    print("청크의 수 :", len(split_chunks))
    all_chunks.extend(split_chunks)

# %%
split_chunks(pdf_files)
# Out:
# Pdf Load:   8%|▊         | 1/12 [00:13<02:31, 13.80s/it]
# 문단 개수: 28
# 평균 문단 길이: 1494
# 최소 문단 길이: 55
# 최대 문단 길이: 3228
# 추천 chunk_size: 3550
# 추천 chunk_overlap: 532
# 청크의 수 : 28
# Pdf Load:  25%|██▌       | 3/12 [00:18<00:42,  4.70s/it]
# 문단 개수: 112
# 평균 문단 길이: 514
# 최소 문단 길이: 0
# 최대 문단 길이: 1167
# 추천 chunk_size: 1283
# 추천 chunk_overlap: 192
# 청크의 수 : 99
#
# 문단 개수: 17
# 평균 문단 길이: 1629
# 최소 문단 길이: 1019
# 최대 문단 길이: 1996
# 추천 chunk_size: 2195
# 추천 chunk_overlap: 329
# 청크의 수 : 17
#
# 문단 개수: 6
# 평균 문단 길이: 1439
# 최소 문단 길이: 178
# 최대 문단 길이: 1780
# 추천 chunk_size: 1958
# 추천 chunk_overlap: 293
# 청크의 수 : 6
# Pdf Load:  42%|████▏     | 5/12 [00:19<00:14,  2.13s/it]
# 문단 개수: 21
# 평균 문단 길이: 1878
# 최소 문단 길이: 1405
# 최대 문단 길이: 2093
# 추천 chunk_size: 2302
# 추천 chunk_overlap: 345
# 청크의 수 : 21
# Pdf Load:  50%|█████     | 6/12 [00:19<00:09,  1.64s/it]
# 문단 개수: 36
# 평균 문단 길이: 1776
# 최소 문단 길이: 982
# 최대 문단 길이: 2336
# 추천 chunk_size: 2569
# 추천 chunk_overlap: 385
# 청크의 수 : 36
# Pdf Load:  58%|█████▊    | 7/12 [00:19<00:06,  1.28s/it]
# 문단 개수: 34
# 평균 문단 길이: 1427
# 최소 문단 길이: 248
# 최대 문단 길이: 1761
# 추천 chunk_size: 1937
# 추천 chunk_overlap: 290
# 청크의 수 : 34
# Pdf Load:  67%|██████▋   | 8/12 [00:20<00:04,  1.06s/it]
# 문단 개수: 44
# 평균 문단 길이: 1819
# 최소 문단 길이: 388
# 최대 문단 길이: 2271
# 추천 chunk_size: 2498
# 추천 chunk_overlap: 374
# 청크의 수 : 44
# Pdf Load:  75%|███████▌  | 9/12 [00:20<00:02,  1.11it/s]
# 문단 개수: 41
# 평균 문단 길이: 1788
# 최소 문단 길이: 878
# 최대 문단 길이: 2187
# 추천 chunk_size: 2405
# 추천 chunk_overlap: 360
# 청크의 수 : 41
# Pdf Load:  83%|████████▎ | 10/12 [00:52<00:20, 10.11s/it]
# 문단 개수: 732
# 평균 문단 길이: 986
# 최소 문단 길이: 0
# 최대 문단 길이: 2910
# 추천 chunk_size: 2956
# 추천 chunk_overlap: 443
# 청크의 수 : 720
# Pdf Load:  92%|█████████▏| 11/12 [01:07<00:11, 11.55s/it]
# 문단 개수: 166
# 평균 문단 길이: 837
# 최소 문단 길이: 0
# 최대 문단 길이: 1588
# 추천 chunk_size: 1746
# 추천 chunk_overlap: 261
# 청크의 수 : 163
# Pdf Load: 100%|██████████| 12/12 [01:09<00:00,  5.83s/it]
# 문단 개수: 63
# 평균 문단 길이: 433
# 최소 문단 길이: 0
# 최대 문단 길이: 1092
# 추천 chunk_size: 1201
# 추천 chunk_overlap: 180
# 청크의 수 : 61

# %% [markdown]
# ## build retriever

# %%
def build_retriever(all_chunks,
                               embedding_model: str = "sentence-transformers/all-mpnet-base-v2"
                               ):
  # FAISS retriever
  embeddings = HuggingFaceEmbeddings(model_name=embedding_model,
                                     cache_folder="/content/drive/MyDrive/1데이콘/2025금융AIChallenge금융AI모델경쟁/dataset/faiss_embedding_models")
  vectordb = FAISS.from_documents(all_chunks, embeddings)
  vector_retriever = vectordb.as_retriever(search_type = 'mmr',
                                    search_kwargs = {'k':5, 'fetch_k': 20, 'lambda_mult': 0.5}
                                    )

  # BM25 retriever
  tokenized_docs = [doc.page_content.split() for doc in all_chunks]
  bm25_okapi = BM25Okapi(tokenized_docs)
  bm25_retriever = BM25Retriever.from_documents(all_chunks)

  return embeddings, vectordb, vector_retriever, bm25_okapi, bm25_retriever

# %%
faiss_embeddings, faiss_vectordb, faiss_vector_retriever, bm25_okapi, bm25_retriever = build_retriever(all_chunks)

# %%
# vectordb (FAISS 인덱스) 저장

# faiss_retriever 내부의 vectorstore 가져오기
faiss_vectordb.save_local("/content/drive/MyDrive/1데이콘/2025금융AIChallenge금융AI모델경쟁/dataset/faiss_vectordb")

# bm25_retriever 내부의 vectorstore 가져오기
with open("/content/drive/MyDrive/1데이콘/2025금융AIChallenge금융AI모델경쟁/dataset/bm25_vectordb/bm25_model.pkl", "wb") as f:
    pickle.dump(bm25_okapi, f)

# %% [markdown]
# # Model load & Quantization

# %%
model_name = 'LGAI-EXAONE/EXAONE-3.5-7.8B-Instruct'

# 양자화
# bnb_config = BitsAndBytesConfig(
#     load_in_4bit = True,
#     bnb_4bit_quant_type = "nf4",
#     bnb_4bit_use_double_quant = True,
#     bnb_4bit_compute_dtype = torch.bfloat16
# )

# awq_config = AWQConfig(
#     bits=8,
#     group_size=128,
#     module_skip_list=["lm_head"]
# )

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map={"":0},
    trust_remote_code=True,
    # quantization_config = bnb_config
)

tokenizer = AutoTokenizer.from_pretrained(model_name)

# 그래디언트 체크포인팅 활성화(메모리 절약)
model.gradient_checkpointing_enable()

# 모델을 훈련에 적합하게 조성
model = prepare_model_for_kbit_training(model)
# Out:
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
# for name, module in model.named_modules():
#     if "attn" in name.lower() or "attention" in name.lower():
#         print(name)

# %%
# LoRA 설정
lora_config = LoraConfig(
    lora_alpha = 32,
    lora_dropout = 0.1,
    r = 16,
    task_type="CAUSAL_LM",
    bias = "none",
    target_modules = [
        # 'query_key_value'
        'q_proj',
        'k_proj',
        'v_proj',
        'o_proj'
    ]
  )

# 모델에 LoRA 적용
model = get_peft_model(model, lora_config)

# 훈련 가능한 파라미터 확인
model.print_trainable_parameters()
# Out:
# trainable params: 9,437,184 || all params: 7,827,886,080 || trainable%: 0.1206

# %% [markdown]
# # Inference

# %% [markdown]
# ## Define Untils

# %%
# 객관식 여부 판단 함수
def is_multiple_choice(question_text):
    """
    객관식 여부를 판단: 2개 이상의 숫자 선택지가 줄 단위로 존재할 경우 객관식으로 간주
    """
    lines = question_text.strip().split("\n")
    option_count = sum(bool(re.match(r"^\s*[1-9]?\s", line)) for line in lines)
    return option_count >= 2

# %%
# 질문과 선택지 분리 함수
def extract_question_and_choices(full_text):
    """
    전체 질문 문자열에서 질문 본문과 선택지 리스트를 분리
    """
    lines = full_text.strip().split("\n")
    q_lines = []
    options = []

    for line in lines:
        if re.match(r"^\s*[1-9]?\s", line):
            options.append(line.strip())
        else:
            q_lines.append(line.strip())

    question = " ".join(q_lines)
    return question, options

# %%
# 후처리 함수
def extract_answer_only(generated_text: str, original_question: str) -> str:
    """
    - "답변:" 이후 텍스트만 추출
    - 객관식 문제면: 정답 숫자만 추출 (실패 시 전체 텍스트 또는 기본값 반환)
    - 주관식 문제면: 전체 텍스트 그대로 반환
    - 공백 또는 빈 응답 방지: 최소 "미응답" 반환
    """
    # "답변:" 기준으로 텍스트 분리
    if "답변:" in generated_text:
        text = generated_text.split("답변:")[-1].strip()
    else:
        text = generated_text.strip()

    # 공백 또는 빈 문자열일 경우 기본값 지정
    if not text:
        return "미응답"

    # 객관식 여부 판단
    is_mc = is_multiple_choice(original_question)

    if is_mc:
        # 숫자만 추출
        match = re.match(r"\D*([1-9]?)", text)
        # match = re.search(r"([1-9]?)", text)
        if match:
            return match.group(1)
        else:
            # 숫자 추출 실패 시 "0" 반환
            return "0"
    else:
        return text

# %%
# 하이브리드 검색기
def hybrid_search(question: str, top_k: int, bm25_weight: int, faiss_weight: int):
  # bm25 점수
  tokenized_question = question.split()
  bm25_scores = bm25_okapi.get_scores(tokenized_question)
  bm25_scores_norm = bm25_scores / (np.max(bm25_scores) + 1e-8)

  # faiss 점수
  ques_embedding = faiss_embeddings.embed_query(question)
  D, I = faiss_vectordb.index.search(np.array([ques_embedding]), len(all_chunks))
  faiss_scores = np.zeros(len(all_chunks))
  faiss_scores[I[0]] = (np.max(D[0]) - D[0]) / (np.max(D[0]) - np.min(D[0]) + 1e-8)

  # 가중합
  combined_scores = bm25_weight * bm25_scores_norm + faiss_weight * faiss_scores

  # Top-K 문서 선택
  top_indices = np.argsort(combined_scores)[::-1][:top_k]
  top_docs = [all_chunks[i] for i in top_indices]

  return top_docs, combined_scores

# %%
# 프롬프트 생성기
def make_prompt_auto(text: str, top_docs: str) -> str:
    """RAG 컨텍스트를 포함해 객관식/주관식 프롬프트를 자동 구성"""
    if is_multiple_choice(text):
        question, options = extract_question_and_choices(text)
        prompt = (
            "당신은 금융보안 전문가입니다.\n"
            "아래 질문에 대해 적절한 **정답 선택지 번호만 출력**하세요. 다른 단어/설명 금지.\n\n"
            "예: 1 / 2/ 3/ 4/ 5\n\n"
            f"참고문서: {top_docs}\n\n"
            f"질문: {question}\n"
            "선택지:\n"
            f"{'\n'.join(options)}\n\n"
            "답변:"
        )
    else:
        prompt = (
            "당신은 금융보안 전문가입니다.\n"
            "아래 주관식 질문에 대해 정확하고 간략한 설명을 작성하세요.\n\n"
            "단, 참고 문서를 바탕으로 답을 구성하되 검색된 내용을 그대로 복사하지 말고 반드시 **재구성, 요약, 재작성**해서 답변해야 합니다.\n\n"
            f"참고문서: {top_docs}\n\n"
            f"질문: {text}\n\n"
            "답변:"
        )
    return prompt

# %% [markdown]
# ## Finetunning Model Load

# %%
adapter_path = "/content/drive/MyDrive/1데이콘/2025금융AIChallenge금융AI모델경쟁/dataset/finetunning_model8/checkpoint-1104"

# 추론만 고려
fine_model = PeftModelForCausalLM.from_pretrained(model, adapter_path)
fine_model = fine_model.merge_and_unload().to("cuda")

# %%
# 추가 파인튜닝
# fine_model = AutoPeftModelForCausalLM.from_pretrained(
#     adapter_path,
#     torch_dtype="auto",
#     device_map="auto"
# )

# fine_model = PeftModelForCausalLM.from_pretrained(model, adapter_path)
# fine_model = fine_model.merge_and_unload()

# # 여기서 다시 로드 (Hugging Face 방식)
# fine_model.save_pretrained("merged_model")
# tokenizer.save_pretrained("merged_model")

# from transformers import AutoModelForCausalLM, AutoTokenizer
# fine_model = AutoModelForCausalLM.from_pretrained("merged_model").to("cuda")
# tokenizer = AutoTokenizer.from_pretrained("merged_model")

# pipe = pipeline("text-generation", model=fine_model, tokenizer=tokenizer)


# pipe = pipeline("text-generation",
#                 model=fine_model,
#                 tokenizer=tokenizer)

# %% [markdown]
# ## Test data Load

# %%
test = pd.read_csv('/content/drive/MyDrive/1데이콘/2025금융AIChallenge금융AI모델경쟁/dataset/test.csv')

# %% [markdown]
# ## Inference

# %%
def inference(question, fine_model, tokenizer, faiss_vectordb, bm25_okapi,
              top_k: int, bm25_weight: int, faiss_weight: int):

  top_docs = hybrid_search(question, top_k, bm25_weight, faiss_weight)
  prompt = make_prompt_auto(question, top_docs)
  inputs = tokenizer(prompt, return_tensors = 'pt').to('cuda')

  # 객관식
  if is_multiple_choice(question):
    output_ids = fine_model.generate(
        **inputs,
        max_new_tokens=128,
        do_sample=False,
    )
  else:
    output_ids = fine_model.generate(
        **inputs,
        max_new_tokens=256,
        do_sample=True,
        temperature=0.3,
        top_p=0.9
      )

  output_text = tokenizer.decode(output_ids[0], skip_special_tokens=True)
  pred_answer = extract_answer_only(output_text, original_question=q)

  return pred_answer

# %%
torch.cuda.empty_cache()

preds = []

for q in tqdm.tqdm(test['Question'], desc='Inference'):
  answer = inference(q, fine_model, tokenizer, faiss_vectordb, bm25_okapi,
              top_k=7, bm25_weight=0.1, faiss_weight=0.9)
  preds.append(answer)
# Out:
# Inference: 100%|██████████| 515/515 [54:08<00:00,  6.31s/it]

# %% [markdown]
# # Submission

# %%
sample_submission = pd.read_csv('/content/drive/MyDrive/1데이콘/2025금융AIChallenge금융AI모델경쟁/dataset/sample_submission.csv')
sample_submission['Answer'] = preds
sample_submission.to_csv('/content/drive/MyDrive/1데이콘/2025금융AIChallenge금융AI모델경쟁/submission_final.csv', index=False, encoding='utf-8-sig')
sample_submission.to_csv('submission_final.csv', index=False, encoding='utf-8-sig')

files.download('submission_final.csv')

# %%
preds
# Out:
# ['5',
#  '2',
#  '1',
#  '3',
#  '트로이 목마 기반의 원격제어 악성코드(RAT)는 사용자에게 유용한 프로그램처럼 보이지만 실제로는 악성 코드를 설치하여 시스템을 제어하는 악성 소프트웨어입니다. 주요 특징은 다음과 같습니다:\n\n1. **위장**: 사용자에게 유용한 프로그램처럼 보이도록 설계되어 있어, 사용자가 의심 없이 설치하게 만듭니다.\n2. **원격 제어**: 설치된 후에는 공격자가 원격으로 시스템을 제어할 수 있는 기능을 제공합니다.\n3. **다양한 기능**: 파일 업로드/다운로드, 키로깅, 화면 캡처, 시스템 정보 수집 등 다양한 악성 행위를 수행할 수 있습니다.\n\n주요 탐지 지표는 다음과 같습니다:\n\n1. **파일 특성**: 악성코드의 파일 특성을 분석하여 정상적인 프로그램과 다른 패턴을 탐지합니다. 예를 들어, 악성코드는 일반적으로 압축되어 있거나, 특정 시그니처를 가질 수 있습니다.\n2. **행동 패턴**: 악성코드의 행동 패턴을 모니터링하여 의심스러운 활동을 탐지합니다. 예를 들어, 정상적인 프로세스 외에서 실행되는 경우, 네트워크 통신 패턴의 이상 등이 있습니다',
#  '4',
#  '2',
#  '전자금융거래법에 따라 이용자가 금융 분쟁조정을 신청할 수 있는 기관은 금융감독원입니다.',
#  '5',
#  '3',
#  '1',
#  '4',
#  '1',
#  '4',
#  '5',
#  '4',
#  '4',
#  '4',
#  '1',
#  '1',
#  '4',
#  '1',
#  '3',
#  '5',
#  '2',
#  '3',
#  '3',
#  '3',
#  '1',
#  '2',
#  '3',
#  '2',
#  '1',
#  '1',
#  '1',
#  '2',
#  '5',
#  '4',
#  '5',
#  '4',
#  '1',
#  '5',
#  '3',
#  '4',
#  '4',
#  '1',
#  '3',
#  '1',
#  '1',
#  '4',
#  '1',
#  '3',
#  '3',
#  '2',
#  '4',
#  '4',
#  '1',
#  '5',
#  '3',
#  '2',
#  '4',
#  '4',
#  '4',
#  '5',
#  '1',
#  '3',
#  '1',
#  '1',
#  '4',
#  '3',
#  '4',
#  '3',
#  '3',
#  '1',
#  '4',
#  '2',
#  '3',
#  '4',
#  '1',
#  '4',
#  '5',
#  '1',
#  '금융권은 딥페이크 기술 악용에 대비하여 다각적인 대응 방안을 마련하고 있습니다. 먼저, 고객 인식 제고를 위해 딥페이크 기술의 위험성과 사기 유형에 대한 교육 캠페인을 진행하고 있습니다. 또한, 금융기관 내부에서는 AI 기반의 딥페이크 탐지 시스템을 도입하여 의심스러운 거래나 콘텐츠를 실시간으로 감지하고 있습니다. 금융감독원과의 협력 하에 정책적 대응을 강화하고 있으며, 이는 금융사기 대응 매뉴얼 업데이트와 함께 이루어집니다. 이러한 조치들은 딥페이크 기술의 악용을 최소화하고 고객 보호를 강화하기 위한 종합적인 접근 방식을 반영하고 있습니다.',
#  '3',
#  '2',
#  '1',
#  '3',
#  '1',
#  '2',
#  '1',
#  '3',
#  '3',
#  '3',
#  '3',
#  '5',
#  '2',
#  '2',
#  '3',
#  '3',
#  '5',
#  '3',
#  '디지털 지갑에서 주요 보안 위협으로는 개인정보 유출, 악성코드 감염, 딥페이크 악용, 공급망 공격 등이 있습니다. 개인정보 유출은 사용자의 민감한 정보가 노출되어 금융사기로 이어질 수 있으며, 악성코드 감염은 악성 앱을 통해 기기가 해킹되어 금융 정보가 탈취될 위험이 있습니다. 딥페이크 기술을 이용한 사기는 가짜 신원을 통해 금융 사기를 시도하며, 공급망 공격은 제3자 서비스나 소프트웨어를 통해 시스템에 침입하여 금융 정보를 탈취하는 위협입니다. 이러한 위협들은 디지털 지갑의 안전성을 크게 위협하며, 사용자의 금융 정보 보호를 위해 강력한 보안 대책이 필요합니다.',
#  '개인정보 접근 권한 검토는 개인정보 처리자가 개인정보에 접근할 수 있는 권한을 검토하고, 필요한 접근 권한만 부여하며, 접근 권한 부여 기준을 명확히 정의하는 과정입니다. 이는 개인정보 보호를 위해 불필요한 접근을 차단하고, 개인정보 유출 위험을 최소화하는 것을 목적으로 합니다. 검토 결과는 문서화하여 보관해야 합니다.',
#  '1',
#  '1',
#  '4',
#  '2',
#  '2',
#  '2',
#  '4',
#  '1',
#  '1',
#  '4',
#  '3',
#  '1',
#  '1',
#  '1',
#  '4',
#  '5',
#  '2',
#  '2',
#  '3',
#  '3',
#  '5',
#  '3',
#  '2',
#  '정보보호의 3대 요소에 해당하는 보안 목표는 다음과 같습니다:\n\n1. **기밀성 (Confidentiality)**: 정보가 권한이 있는 사람들만 접근할 수 있도록 보호하는 것을 의미합니다. 즉, 비인가된 사용자들이 정보에 접근하거나 정보가 유출되는 것을 방지합니다.\n\n2. **무결성 (Integrity)**: 정보가 정확하고 완전하며, 권한이 있는 사용자에 의해 적절히 변경될 수 있음을 보장하는 것을 의미합니다. 정보의 변조나 오류 없이 신뢰할 수 있는 상태를 유지하는 것을 포함합니다.\n\n3. **가용성 (Availability)**: 정보와 시스템이 필요할 때 안전하게 접근 가능하도록 보장하는 것을 의미합니다. 시스템 장애나 공격으로부터 보호하여 정상적인 운영이 가능하도록 합니다.',
#  '5',
#  '2',
#  '1',
#  '3',
#  '전자금융감독규정상 금융회사의 정보보호 예산은 전체 IT 예산의 최소 7% 이상이어야 합니다. 정보보호 인력의 경우, IT 인력의 최소 5% 이상이 요구됩니다. 이러한 기준은 전자금융거래의 안전성을 확보하기 위한 최소한의 기준으로 설정되어 있습니다.',
#  '1',
#  '2',
#  '1',
#  '2',
#  '3',
#  '4',
#  '1',
#  '1',
#  '1',
#  '5',
#  '3',
#  '2',
#  '5',
#  '5',
#  '3',
#  '4',
#  '4',
#  '3',
#  '3',
#  '4',
#  '4',
#  '2',
#  '2',
#  '2',
#  '3',
#  '2',
#  '3',
#  '2',
#  '3',
#  '1',
#  '1',
#  '1',
#  '2',
#  '2',
#  '2',
#  '4',
#  '3',
#  '2',
#  '2',
#  '4',
#  '4',
#  '3',
#  '3',
#  '3',
#  '2',
#  '2',
#  '3',
#  '2',
#  '1',
#  '3',
#  'SMTP 프로토콜은 이메일 전송 과정에서 메시지의 인증, 암호화, 무결성을 보장하는 데 중점을 둡니다. 이를 통해 이메일 내용이 송수신 과정에서 변조되지 않았음을 확인하고, 외부 공격자로부터 보호하는 역할을 수행합니다. 특히, TLS(Transport Layer Security)와 같은 보안 프로토콜을 통해 이메일 데이터를 암호화하여 전송함으로써 보안성을 강화합니다. 이는 이메일 서비스의 안전성을 크게 향상시키는 핵심적인 기능입니다.',
#  '3',
#  '4',
#  '1',
#  '4',
#  '4',
#  '3',
#  '2',
#  '1',
#  '4',
#  '4',
#  '4',
#  '5',
#  '4',
#  '2',
#  '4',
#  '2',
#  'ID/PW 기반 인증 환경에서 발생할 수 있는 대표적인 공격 유형과 그에 대한 대응 방안은 다음과 같습니다.\n\n1. **스니핑 공격**:\n   - **공격 유형**: 공격자가 네트워크 트래픽을 가로채서 사용자의 ID와 비밀번호를 탈취하는 공격입니다. 특히 공용 Wi-Fi 환경에서 쉽게 발생할 수 있습니다.\n   - **대응 방안**: HTTPS 프로토콜을 사용하여 데이터를 암호화하고, SSL/TLS 인증서를 통해 통신의 무결성을 보장합니다. 또한, 네트워크 트래픽 모니터링 시스템을 도입하여 이상 트래픽을 탐지하고 차단할 수 있습니다.\n\n2. **키로거 공격**:\n   - **공격 유형**: 키보드 입력을 가로채어 사용자의 비밀번호를 탈취하는 공격입니다. 물리적으로 키보드에 설치된 키로거 장치를 사용하거나 소프트웨어 키로거를 통해 이루어집니다.\n   - **대응 방안**: 가상 키보드나 보안 키보드를 사용하여 물리적 키로거의 위협을 차단하고, 소프트웨어 키로거 방지 소프트웨어를 설치하여 소프트웨어 공격을 방어합니다. 또한, 비밀번호 정책을 강화하여 복잡하고 긴 비밀번호 사용을 권장하고,',
#  '3',
#  '3',
#  '1',
#  '4',
#  '5',
#  '전자자금이체의 지급 효력 발생 시점은 전자금융거래법에 따라 다르게 정의됩니다. 선불전자지급수단 및 전자화폐로 지급하는 경우에는 수취인이 지정한 전자적 장치에 거래 지시 금액의 정보가 도달한 순간부터 효력이 발생합니다. 반면, 그 외의 전자지급수단을 통한 지급의 경우에는 수취인의 계좌가 개설된 금융회사나 전자금융업자의 전자적 장치에 거래 지시 금액의 정보가 입력 완료된 시점부터 효력이 발생합니다. 또한, 총자산 규모를 고려한 대통령령에 따라 지정된 금융회사나 전자금융업자는 이용자의 요청에 따라 거래 지시 후 일정 시간이 경과한 후에 지급 효력이 발생하도록 할 수 있습니다. 이는 이용자의 자금 운용 편의성과 안전성을 동시에 고려한 조치입니다.',
#  '5',
#  '2',
#  '3',
#  '2',
#  '3',
#  '4',
#  '1',
#  '1',
#  '5',
#  '2',
#  '3',
#  '3',
#  '2',
#  '3',
#  '4',
#  '3',
#  '2',
#  '2',
#  '2',
#  '2',
#  '1',
#  '3',
#  '5',
#  '4',
#  '1',
#  '2',
#  '3',
#  '5',
#  '2',
#  '4',
#  '4',
#  '4',
#  '3',
#  '4',
#  '3',
#  '5',
#  '3',
#  '2',
#  '5',
#  'DNSSEC의 주요 기능은 도메인 이름 시스템(DNS)의 응답 데이터 무결성과 인증을 보장하는 것입니다. 이를 통해 DNS 스푸핑 공격과 같은 보안 위협을 방지할 수 있습니다. DNS 스푸핑 공격은 공격자가 DNS 응답을 조작하여 사용자를 피싱 사이트로 유도하는 공격으로, DNSSEC을 통해 이러한 공격을 방어하고 사용자의 개인정보와 금융 정보를 보호할 수 있습니다.',
#  '2',
#  '2',
#  '3',
#  '5',
#  '5',
#  '3',
#  '4',
#  '2',
#  '3',
#  '1',
#  '4',
#  '4',
#  '4',
#  '2',
#  '3',
#  '1',
#  '3',
#  '2',
#  '1',
#  '4',
#  '2',
#  '5',
#  '1',
#  '1',
#  '2',
#  '2',
#  '4',
#  '4',
#  '1',
#  '4',
#  '4',
#  '3',
#  '4',
#  '2',
#  '5',
#  '2',
#  '1',
#  '1',
#  '3',
#  '5',
#  '4',
#  '2',
#  '3',
#  '3',
#  '3',
#  '1',
#  '2',
#  '3',
#  '2',
#  '3',
#  '2',
#  '2',
#  '3',
#  '4',
#  '3',
#  '1',
#  '1',
#  '1',
#  '1',
#  '5',
#  '1',
#  '1',
#  '2',
#  '3',
#  '1',
#  '1',
#  '4',
#  '4',
#  '3',
#  '5',
#  '3',
#  '2',
#  '1',
#  '1',
#  '1',
#  '4',
#  '2',
#  '1',
#  '4',
#  '3',
#  '1',
#  '3',
#  '4',
#  '2',
#  '1',
#  '4',
#  '2',
#  '1',
#  '4',
#  '4',
#  '4',
#  '5',
#  '4',
#  '2',
#  '4',
#  '3',
#  '4',
#  '2',
#  '2',
#  '3',
#  '4',
#  '4',
#  '4',
#  '2',
#  '1',
#  '2',
#  '4',
#  '1',
#  '4',
#  '5',
#  '1',
#  '3',
#  '1',
#  '1',
#  '1',
#  '2',
#  '1',
#  '3',
#  '1',
#  '2',
#  '1',
#  '3',
#  '2',
#  '3',
#  '5',
#  '1',
#  '2',
#  '2',
#  '4',
#  '1',
#  '2',
#  '4',
#  '1',
#  '3',
#  '1',
#  '4',
#  '3',
#  '2',
#  '3',
#  '4',
#  '5',
#  '2',
#  '1',
#  '4',
#  '4',
#  '3',
#  '4',
#  '1',
#  '3',
#  '3',
#  '2',
#  '3',
#  '3',
#  '3',
#  '1',
#  '1',
#  '4',
#  '1',
#  '4',
#  '1',
#  '3',
#  '1',
#  '3',
#  '4',
#  '1',
#  '4',
#  '3',
#  '4',
#  '1',
#  '2',
#  'VLAN은 물리적으로 분리되어 있는 네트워크를 논리적으로 분할하여 관리 효율성을 높이고, 보안을 강화하며, 트래픽을 분리하여 성능을 개선하는 기능을 제공합니다. 이를 통해 네트워크 관리가 용이해지고, 특정 VLAN 내에서만 통신이 가능하여 보안성이 향상됩니다. 또한, VLAN을 통해 트래픽을 분리함으로써 네트워크의 혼잡을 줄이고 성능을 개선할 수 있습니다.',
#  '4',
#  '1',
#  '1',
#  '5',
#  '4',
#  '5',
#  '3',
#  '2',
#  '4',
#  '1',
#  '2',
#  '1',
#  '5',
#  '3',
#  '4',
#  '4',
#  '3',
#  '2',
#  '1',
#  '4',
#  '3',
#  '4',
#  '3',
#  '5',
#  '2',
#  '5',
#  '3',
#  '2',
#  '4',
#  '2',
#  '3',
#  '2',
#  '1',
#  '4',
#  '4',
#  '3',
#  '2',
#  '2',
#  '4',
#  '3',
#  '4',
#  '금융기관은 개인신용평점 하락 가능성에 대해 설명해야 할 주요 내용은 다음과 같습니다:\n1. 해당 금융거래로 인해 개인신용평가회사가 개인신용평점을 산출할 때 신용정보주체에게 불이익이 발생할 수 있다는 사실.\n2. 개인신용평점 하락 시 불이익이 발생할 수 있는 금융거래의 종류.\n3. 평균적으로 연체율이 높은 금융권역의 신용공여는 다른 금융권역의 신용공여보다 신용점수 하락 폭이 클 수 있다는 사실.\n4. 평균적으로 연체율이 높은 형태의 신용공여는 일반적인 신용공여보다 신용점수 하락 폭이 클 수 있다는 사실.\n5. 해당 금융거래가 변제나 이에 준하는 방식으로 종료되더라도 일정 기간 동안 개인신용평점 산정에 영향을 미칠 수 있다는 사실.',
#  '3',
#  '2',
#  '4',
#  '2',
#  '2',
#  '1',
#  '4',
#  '4',
#  '4',
#  '3',
#  '4',
#  '5',
#  '특수 계정에 대한 보안조치 방안은 다음과 같습니다: \n1. **계정 분류 및 관리**: 특수 계정을 중요도에 따라 분류하고, 각 계정별로 접근 권한을 차등 부여하여 관리합니다.\n2. **최소 권한 원칙**: 특수 계정은 업무 수행에 필요한 최소한의 권한만 부여하고, 불필요한 권한은 제거합니다.\n3. **정기적인 권한 검토**: 정기적으로 계정의 권한을 검토하여 필요 없는 권한은 즉시 제거합니다.\n4. **계정 접근 로깅 및 모니터링**: 특수 계정의 접근 로그를 상세히 기록하고, 이상 징후를 감지하여 즉시 대응합니다.\n5. **다중 인증(MFA) 적용**: 특수 계정에 대해 다중 인증을 적용하여 추가적인 보안을 강화합니다.\n6. **계정 비밀번호 관리**: 특수 계정의 비밀번호는 복잡도 요구사항을 충족하도록 설정하고, 정기적으로 변경합니다.\n7. **계정 사용 제한**: 특수 계정의 사용을 제한하고, 필요한 경우에만 사용할 수 있도록 합니다.\n8. **정기적인 보안 교육**: 특수 계정을 관리하는 직원들에게 정기적인',
#  '1',
#  '4',
#  '1',
#  '1',
#  '4',
#  '4',
#  '4',
#  '4',
#  '4',
#  '5',
#  '1',
#  '4',
#  '4',
#  '3',
#  '1',
#  '3',
#  '5',
#  '3',
#  '2',
#  '1',
#  '5',
#  '4',
#  '4',
#  '5',
#  '2',
#  '2',
#  '4',
#  '3',
#  '2',
#  '4',
#  '4',
#  '1',
#  '5',
#  '4',
#  '4',
#  '전자금융데이터 보안에서 암호화 방식을 선택할 때 고려해야 할 주요 기준은 다음과 같습니다:\n\n1. **안전성 및 보안 강도**: 선택한 암호화 알고리즘이 현재의 보안 위협에 대응할 수 있는 충분한 안전성과 보안 강도를 갖추고 있는지 확인해야 합니다. 이는 알고리즘이 국내외 권고 표준에 부합하는지 검토하는 것을 포함합니다.\n\n2. **키 관리**: 암호화 키의 안전한 생성, 주입, 운용, 갱신, 폐기 등 키 관리 전반에 걸친 절차와 방법이 체계적으로 마련되어 있는지 확인해야 합니다. 키 관리의 부실은 암호화의 효과를 크게 저하시킬 수 있습니다.\n\n3. **법규 준수**: 암호화 방식 선택 시 관련 법규와 규정을 준수해야 합니다. 예를 들어, 개인정보보호법, 정보통신망 이용촉진 및 정보보호 등에 관한 법률, 전자금융거래법 등에서 요구하는 암호화 기준을 충족해야 합니다.\n\n4. **알고리즘의 적합성**: 데이터의 특성과 사용 목적에 따라 적합한 암호화 알고리즘을 선택해야 합니다. 대칭키 암호화와 공개키 암호화 중 어떤 방식이',
#  '3',
#  '3',
#  '3',
#  '4',
#  '3',
#  '4',
#  '1']
